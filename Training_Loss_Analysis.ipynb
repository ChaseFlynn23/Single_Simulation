# %% [markdown]
# # Loss & Validation Loss Graphs

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
# Latent Space 1 (0-1)
folder_name_1 = 'AE_Training_Model_1'
file_name_1 = '1_Latent_Space'

# Latent Space 2 (0-1)
folder_name_2 = 'AE_Training_Model_2'
file_name_2 = '1_Latent_Space'

# Latent Space 3 (0-1)
folder_name_3 = 'AE_Training_Model_3'
file_name_3 = '1_Latent_Space'

# Latent Space 4 (0-1)
folder_name_4 = 'AE_Training_Model_4'
file_name_4 = '1_Latent_Space'

# Latent Space 5 (0-0)
folder_name_5 = 'AE_Training_Model_5'
file_name_5 = '0_Latent_Space'

# Latent Space 6 (0-1)
folder_name_6 = 'AE_Training_Model_6'
file_name_6 = '1_Latent_Space'

# Latent Space 7 (0-1)
folder_name_7 = 'AE_Training_Model_7'
file_name_7 = '1_Latent_Space'

# %% [markdown]
# # Latent Space 1

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_1, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_1}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_1, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_1} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# Minimum Loss: 0.001263 at Epoch 1746
# Minimum Validation Loss: 0.001282 at Epoch 1822

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_1 = pd.read_pickle(f'{folder_name_1}/{file_name_1}')
latent_1 = latent_1.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_1.set_index('index', inplace=True)
latent_1.index.name = None

# %%
latent_1['z'] = pd.to_numeric(latent_1['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_1.x,latent_1.y, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 20', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()
# Out:
# /tmp/ipykernel_84644/2725662695.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter (latent_1.x,latent_1.y, cmap="coolwarm", s = 1, alpha=1)

# %% [markdown]
# # Latent Space 2

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_2, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_2}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_2, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_2} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# Minimum Loss: 0.001040 at Epoch 1045
# Minimum Validation Loss: 0.001091 at Epoch 1050

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_2 = pd.read_pickle(f'{folder_name_2}/{file_name_2}')
latent_2 = latent_2.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_2.set_index('index', inplace=True)
latent_2.index.name = None

# %%
latent_2['z'] = pd.to_numeric(latent_2['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_2.x,latent_2.y, c=latent_2.z, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 16', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()

# %% [markdown]
# # Latent Space 3

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_3, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_3}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_3, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_3} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# Minimum Loss: 0.001385 at Epoch 160
# Minimum Validation Loss: 0.001376 at Epoch 158

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_3 = pd.read_pickle(f'{folder_name_3}/{file_name_3}')
latent_3 = latent_3.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_3.set_index('index', inplace=True)
latent_3.index.name = None

# %%
latent_3['z'] = pd.to_numeric(latent_3['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_3.x,latent_3.y, c=latent_3.z, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 20', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()

# %% [markdown]
# # Latent Space 4

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_4, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_4}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_4, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_4} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# Minimum Loss: 0.005878 at Epoch 256
# Minimum Validation Loss: 0.005902 at Epoch 1555

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_4 = pd.read_pickle(f'{folder_name_4}/{file_name_4}')
latent_4 = latent_4.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_4.set_index('index', inplace=True)
latent_4.index.name = None

# %%
latent_4['z'] = pd.to_numeric(latent_4['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_4.x,latent_4.y, c=latent_4.z, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 13', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()

# %% [markdown]
# # Latent Space 5

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_5, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_5}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_5, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_5} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# File not found: AE_Training_Model_5/1_Autoencoder_Training_History
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Minimum Loss: 0.001085 at Epoch 577
# Minimum Validation Loss: 0.001134 at Epoch 577
# File not found: AE_Training_Model_5/1_Autoencoder_Training_History

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_5 = pd.read_pickle(f'{folder_name_5}/{file_name_5}')
latent_5 = latent_5.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_5.set_index('index', inplace=True)
latent_5.index.name = None

# %%
latent_5['z'] = pd.to_numeric(latent_5['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_5.x,latent_5.y, c=latent_5.z, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 13', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()

# %% [markdown]
# # Latent Space 6

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_6, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_6}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_6, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_6} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# Minimum Loss: 0.000919 at Epoch 1914
# Minimum Validation Loss: 0.001017 at Epoch 1841

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_6 = pd.read_pickle(f'{folder_name_6}/{file_name_6}')
latent_6 = latent_6.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_6.set_index('index', inplace=True)
latent_6.index.name = None

# %%
latent_5['z'] = pd.to_numeric(latent_5['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_5.x,latent_5.y, c=latent_5.z, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 13', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()

# %% [markdown]
# # Latent Space 7

# %%
name = '_Autoencoder_Training_History' 

# Create a figure for plotting
plt.figure(figsize=(12, 8))

# Initialize variables to track the minimum loss and validation loss
min_loss = float('inf')
min_val_loss = float('inf')
min_loss_epoch = None
min_val_loss_epoch = None
cumulative_epochs_1 = 0

for count in range(2):
    file_name = os.path.join(folder_name_7, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_1 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_1 = range(cumulative_epochs_1, cumulative_epochs_1 + num_epochs_1)
        
        # Add labels only for the first epoch set
        if count == 0:
            loss_label = 'Loss'
            val_loss_label = 'Validation Loss'
        else:
            loss_label = None
            val_loss_label = None

        # Plot the training history with the adjusted epoch range
        plt.plot(epoch_range_1, training_history['loss'], label=loss_label)
        plt.plot(epoch_range_1, training_history['val_loss'], label=val_loss_label)

        # Check and update minimum loss and validation loss
        local_min_loss = training_history['loss'].min()
        local_min_val_loss = training_history['val_loss'].min()
        local_min_loss_epoch = training_history['loss'].idxmin()
        local_min_val_loss_epoch = training_history['val_loss'].idxmin()

        if local_min_loss < min_loss:
            min_loss = local_min_loss
            min_loss_epoch = local_min_loss_epoch + cumulative_epochs_1
        if local_min_val_loss < min_val_loss:
            min_val_loss = local_min_val_loss
            min_val_loss_epoch = local_min_val_loss_epoch + cumulative_epochs_1

        # Update the cumulative number of epochs
        cumulative_epochs_1 += num_epochs_1

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Combined Training History for {folder_name_7}')
plt.show()
plt.clf()  

# Print the minimum loss and validation loss with corresponding epochs
print(f"Minimum Loss: {min_loss:.6f} at Epoch {min_loss_epoch}")
print(f"Minimum Validation Loss: {min_val_loss:.6f} at Epoch {min_val_loss_epoch}")

# Figure 2: No Epoch Set 0
plt.figure(figsize=(12, 8))

cumulative_epochs_2 = 0

for count in range(1, 2):
    file_name = os.path.join(folder_name_7, str(count) + name)
    try:
        # Load the training history file
        training_history = pd.read_pickle(file_name)
        
        # Number of epochs in the current training run
        num_epochs_2 = len(training_history)

        # Generate a range of epoch numbers for the current training run
        epoch_range_2 = range(cumulative_epochs_2, cumulative_epochs_2 + num_epochs_2)

        # Plot the training history
        plt.plot(epoch_range_2, training_history['loss'], label='Loss' if count == 1 else None)
        plt.plot(epoch_range_2, training_history['val_loss'], label='Validation Loss' if count == 1 else None)

        # Update the cumulative number of epochs
        cumulative_epochs_2 += num_epochs_2

    except FileNotFoundError:
        print(f"File not found: {file_name}")

# Add legend and labels
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Training History {folder_name_7} (Omitting Epoch Set 0)')
plt.show()
plt.clf()
# Out:
# Minimum Loss: 0.001066 at Epoch 1998
# Minimum Validation Loss: 0.001295 at Epoch 1975

# %% [markdown]
# ## Latent Space Graph

# %%
# read in and plot the original data set
latent_5 = pd.read_pickle(f'{folder_name_5}/{file_name_5}')
latent_5 = latent_5.replace({'trajectory-0.0': '0', 'trajectory-1.0': '1'}).infer_objects()
latent_5.set_index('index', inplace=True)
latent_5.index.name = None

# %%
latent_5['z'] = pd.to_numeric(latent_5['z'], errors='coerce')

plt.figure(figsize=(18,12))
plt.scatter (latent_5.x,latent_5.y, c=latent_5.z, cmap="coolwarm", s = 1, alpha=1)
plt.title('Filtered, epoch set = 13', fontsize = 20)
plt.xlabel('x', fontsize = 16)
plt.ylabel('y', fontsize=16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)

plt.show()
